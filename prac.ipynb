# %%
import pandas as pd
import re
import os
import numpy as np
pd.set_option('max_row',5000)
pd.set_option('max_column',5000)
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'
import seaborn as sns

# %%
fepDf = pd.read_excel("/Users/admin/Dropbox/MRI.xls",'FEP')
fepDf = fepDf[fepDf.timeline=='baseline'] #Selecting only baseline
norDf = pd.read_excel("/Users/admin/Dropbox/MRI.xls",'NOR')
norDf = norDf[norDf.timeline=='baseline']
df = pd.concat([fepDf,norDf])
df.folderName = df.folderName.str[:5]

# %%
# !open /Users/admin/Downloads/CCNC_20140703_dataset_allinonesheet.xlsx

# %%
fepDemoRead = pd.read_excel("/Users/admin/Downloads/CCNC_20140703_dataset_allinonesheet.xlsx",'FEP',skiprows=[0,1])
norDemoRead = pd.read_excel("/Users/admin/Downloads/CCNC_20140703_dataset_allinonesheet.xlsx",'NOR',skiprows=[0,1])

# %%
fepDemoDf = fepDemoRead[[u'Group', u'Hospital ID', u'Patient name', u'BirthDate', u'Sex', u'Education', u'SES(pt)', u'SES(parents)', u'handedness', u'CCNC_20140702_LIST.IQ0',u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'AS1_40', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0']]
fepDemoDf.columns=[u'Group', u'patientNumber', u'koreanName', u'DOB', u'Sex', u'Education', u'SESpt', u'SESparents', u'handedness', u'IQ',u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'AS1_40', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0']

# %%
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==43231692].index,'Education']=14
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==44831778].index,'Education']=14
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==44818302].index,'Education']=16
#'Education','SESpt','SESparents'
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==45726040].index,'Education']=16
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==38531321].index,'Education']=18
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==70352313].index,'Education']=18

norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==41347522].index,'handedness']=2
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==41392452].index,'handedness']=2
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==41975631].index,'handedness']=2
norDemoDf.ix[norDemoDf[norDemoDf.patientNumber==40013509].index,'handedness']=2

fepDemoDf.ix[fepDemoDf[fepDemoDf.patientNumber==40252328].index,'handedness']=2
fepDemoDf.ix[fepDemoDf[fepDemoDf.patientNumber==43217540].index,'handedness']=2
fepDemoDf.ix[fepDemoDf[fepDemoDf.patientNumber==44362164].index,'handedness']=2
fepDemoDf.ix[fepDemoDf[fepDemoDf.patientNumber==44592547].index,'handedness']=2

# %%
demoDf = pd.concat([fepDemoDf,norDemoDf])

# %%
demoDf.columns
# Out:
# Index([u'AS1_40', u'BPRS0', u'DOB', u'Education', u'G1', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'Group', u'HAMA0', u'HAMD', u'IQ', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'SESparents', u'SESpt', u'SOFASpastyr0', u'SOFASpremorbid0', u'SOFASpresent0', u'Sex', u'YMS', u'handedness', u'koreanName', u'patientNumber'], dtype='object')

# %%
allInfoDf = df.merge(demoDf[['koreanName','patientNumber','IQ','Education','SESpt','SESparents','handedness',u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'AS1_40', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0']],on='patientNumber',how='outer')
allInfoDf = allInfoDf[allInfoDf.folderName.notnull()]

# %%
allInfoDf = allInfoDf.applymap(lambda x: x if x != 'missing' else 0)

# %%
allInfoDfWithMRI = allInfoDf[allInfoDf.DKINumber>=151][allInfoDf.DTINumber>=64][allInfoDf.T1Number>=208]

# %%
allInfoDfWithMRI['folderName']=allInfoDfWithMRI.folderName.str[:5]
allInfoDfWithMRI = allInfoDfWithMRI.set_index('folderName')
#make into demographic df
allInfoDfWithMRI = allInfoDfWithMRI[['sex','age','IQ','Education','SESpt','SESparents','handedness','subjectInitial','group','DOB','scanDate',u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'AS1_40', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0']]

# %%
processed = [x[:5] for x in os.listdir('/Volumes/CCNC_3T/KangIk/2014_05_DKI_project') if x.startswith('FEP') or x.startswith('NOR')]
demoDf = allInfoDfWithMRI.ix[processed][['sex','age','IQ','Education','SESpt','SESparents','handedness','group',u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'AS1_40', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0']]
demoDf[demoDf.group=='FEP']
# Out:
#       sex  age   IQ  Education  SESpt  SESparents  handedness group  P1  P2  \
# FEP01   M   18  113         12      4           2           2   FEP   4   2
# FEP02   F   31  107         18      3           1           2   FEP   1   1
# FEP04   F   24  104         12      3           3           2   FEP   3   3
# FEP05   F   23   85         14      3           2           2   FEP   4   4
# FEP06   M   23   95         14      2           2           2   FEP   2   1
# FEP07   M   16   92         11      2           2           2   FEP   2   1
# FEP08   M   27  103         14      4           3           2   FEP   1   1
# FEP09   M   22   84         13      0           3           1   FEP   6   3
# FEP10   F   15   97          9      0           3           2   FEP   5   1
# FEP11   M   22  104         13      4           3           2   FEP   2   2
# FEP12   F   26  120         16      1           4           2   FEP   3   1
# ...

# %%
demoDf
# Out:
#       sex  age   IQ  Education  SESpt  SESparents  handedness group  P1  P2  \
# FEP01   M   18  113         12      4           2           2   FEP   4   2
# FEP02   F   31  107         18      3           1           2   FEP   1   1
# FEP04   F   24  104         12      3           3           2   FEP   3   3
# FEP05   F   23   85         14      3           2           2   FEP   4   4
# FEP06   M   23   95         14      2           2           2   FEP   2   1
# FEP07   M   16   92         11      2           2           2   FEP   2   1
# FEP08   M   27  103         14      4           3           2   FEP   1   1
# FEP09   M   22   84         13      0           3           1   FEP   6   3
# FEP10   F   15   97          9      0           3           2   FEP   5   1
# FEP11   M   22  104         13      4           3           2   FEP   2   2
# FEP12   F   26  120         16      1           4           2   FEP   3   1
# ...

# %% [markdown]
# ## Clinical

# %%
fepDemoRead[[u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'AS1_40', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0']]
# Out:
#     P1  P2  P3  P4  P5  P6  P7  N1  N2  N3  N4  N5  N6  N7  G1  G2  G3  G4  \
# 0    3   3   3   3   2   3   1   1   1   1   3   4   1   1   1   3   2   1
# 1    3   3   4   2   1   2   1   2   3   1   5   2   2   1   1   1   3   1
# 2    3   2   3   1   1   2   1   5   5   4   5   4   5   3   2   2   4   3
# 3    5   3   3   3   1   4   3   3   2   3   2   1   3   3   3   4   3   3
# 4    2   1   1   1   1   3   2   3   1   2   1   4   3   1   2   2   3   2
# 5  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6    5   2   4   2   4   4   2   3   3   3   4   1   2   1   4   3   1   2
# 7  NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 8    4   2   3   1   1   2   1   1   2   1   2   3   1   1   1   3   1   1
# 9    3   1   1   1   1   3   1   3   3   1   4   2   1   1   1   3   2   4
# 10   4   2   1   1   1   3   1   2   2   1   1   2   1   1   1   4   1   2
# ...

# %%
toExtract = []
basicInfo=[u'Group', u'Hospital ID', u'Patient name', u'BirthDate', u'Sex', u'Education', u'SES(pt)', u'SES(parents)', u'handedness', u'CCNC_20140702_LIST.IQ0']

# %%
print fepDemoRead.columns.tolist().index(u'P1')
print fepDemoRead.columns.tolist().index(u'double check')
clinicalScale=fepDemoRead.columns.tolist()[1036:1206]
# Out:
# 1036
# 1206

# %%
for i in fepDemoRead.columns:
    if i.endswith('0'):
        toExtract.append(i)

# %%
csDf = fepDemoRead.ix[:,toExtract+clinicalScale+basicInfo]
csDf = csDf.applymap(lambda x: x if x != 7777 else np.nan)
csDf = csDf.dropna(how='all',axis=1)

# %%
csDf.head()
# Out:
#    P1  P2  P3  P4  P5  P6  P7  N1  N2  N3  N4  N5  N6  N7  G1  G2  G3  G4  G5  \
# 0   3   3   3   3   2   3   1   1   1   1   3   4   1   1   1   3   2   1   1
# 1   3   3   4   2   1   2   1   2   3   1   5   2   2   1   1   1   3   1   2
# 2   3   2   3   1   1   2   1   5   5   4   5   4   5   3   2   2   4   3   4
# 3   5   3   3   3   1   4   3   3   2   3   2   1   3   3   3   4   3   3   1
# 4   2   1   1   1   1   3   2   3   1   2   1   4   3   1   2   2   3   2   1
#
#    G6  G7  G8  G9  G10  G11  G12  G13  G14  G15  G16  AS1_40  GAF  GAFpastyr0  \
# 0   2   1   1   4    3    3    3    2    4    1    3     NaN   42          60
# 1   3   3   1   3    2    2    1    3    1    3    1     NaN   43          58
# 2   2   4   1   2    2    2    4    4    1    4    4     NaN   50          75
# 3   3   1   1   4    1    2    3    2    3    1    3     NaN   34          71
# 4   1   1   2   1    2    3    4    1    1    1    1     NaN   58          85
#
# ...

# %%
csDf.columns
# Out:
# Index([u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'AS1_40', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0', u'입력자.14', u'실시날짜', u'NEO_agree', u'NEO_conscie', u'NEO_extrate', u'NEO_neurot', u'NEO_openne', u'BAS_보상민감', u'BAS_추동', u'BAS_재미추구', u'BIS_행동억제', u'RSQ_안정', u'RSQ_거부', u'RSQ_의존', u'RSQ_두려움', u'PWI total', u'Baratt_인지', u'Baratt_운동', u'Baratt_무계획', u'STAXI_상태', u'STAXI_특성', u'ELSQ total', u'PANAS_posit', u'PANAS_negat', u'EI_인식', u'EI_감정이입', u'EI_사고', u'EI_활용', u'EI_조절', u'SFS_withdra', u'SFS_inter', u'SFS_IP', u'SFS_IC', u'SFS_R', u'SFS_P', u'SFS_E/O', u'TMMS1', u'TMMS2', u'TMMS3', u'EES1', u'EPQ1', u'ECQ1', u'ECQ2', u'SCL-291', u'EF1', u'EI (emotional intensity)1', u'Group', u'Hospital ID', u'Patient name', u'BirthDate', 
# ...

# %% [markdown]
# ## merge

# %%
allInfoDf.columns
# Out:
# Index([u'koreanName_x', u'subjectName', u'subjectInitial', u'group', u'sex', u'age', u'DOB', u'scanDate', u'timeline', u'studyname', u'patientNumber', u'T1Number', u'DTINumber', u'DKINumber', u'RESTNumber', u'REST2Number', u'folderName', u'backUpBy', u'note', u'koreanName_y', u'IQ', u'Education', u'SESpt', u'SESparents', u'handedness'], dtype='object')

# %%
out = pd.merge(csDf,allInfoDf,left_on=u'Hospital ID',right_on=u'patientNumber',how='outer')

# %%
len(out)
# Out:
# 148

# %%
allInfoDf.columns
# Out:
# Index([u'koreanName_x', u'subjectName', u'subjectInitial', u'group', u'sex', u'age', u'DOB', u'scanDate', u'timeline', u'studyname', u'patientNumber', u'T1Number', u'DTINumber', u'DKINumber', u'RESTNumber', u'REST2Number', u'folderName', u'backUpBy', u'note', u'koreanName_y', u'IQ', u'Education', u'SESpt', u'SESparents', u'handedness'], dtype='object')

# %%
allInfoDf.head()
# Out:
#   koreanName_x subjectName subjectInitial group sex  age         DOB  \
# 0          김우진         NaN            KWJ   FEP   M   18  1991-09-24
# 1          임동희         NaN            IDH   FEP   F   31  1978-09-22
# 2          김소연         NaN            KSY   FEP   F   17  1993-01-14
# 3          강성연         NaN            KSY   FEP   F   24  1986-10-07
# 4          정혜리         NaN            JHR   FEP   F   23  1987-02-13
#
#      scanDate  timeline studyname  patientNumber  T1Number DTINumber  \
# 0  2010-06-23  baseline       NaN       72942743       217        84
# 1  2010-07-27  baseline       NaN       40648866       217        74
# 2  2010-08-11  baseline       NaN       40698900       208   missing
# 3  2010-11-18  baseline       NaN       33625827       217        74
# 4  2010-12-17  baseline       NaN       40252328       208        74
#
#   DKINumber RESTNumber REST2Number folderName backUpBy  \
# 0       160       4069         NaN      FEP01      NaN
# ...

# %%
matchedDf = pd.read_csv("/Users/admin/Dropbox/project/DKI_2014/demographics/matchedFEP.csv")
matchedDf.group = matchedDf.group.map({0:'NOR',1:'FEP'})
matchedDf = matchedDf[['index','sex','age','IQ','Education','handedness','group']]
matchedDf = matchedDf.set_index('index')
matchedDf = matchedDf.reset_index()
matchedDf.columns = ['subject','sex','age','IQ','Education','handedness','group']

# %%
matchedDf.head()
# Out:
#   subject sex  age   IQ  Education  handedness group
# 0   FEP01   M   18  113         12           2   FEP
# 1   FEP02   F   31  107         18           2   FEP
# 2   FEP04   F   24  104         12           2   FEP
# 3   FEP05   F   23   85         14           2   FEP
# 4   FEP06   M   23   95         14           2   FEP

# %%
out.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-1ea21df905c3> in <module>()
# ----> 1 out.columns
#
# NameError: name 'out' is not defined

# %%
print out.columns.tolist().index('Group')

clinicalCol=out.columns.tolist()[:87]
# Out:
# 87

# %%
pd.concat([out[['folderName']],out.ix[:,clinicalCol]],axis=1)
# Out:
#     folderName  P1  P2  P3  P4  P5  P6  P7  N1  N2  N3  N4  N5  N6  N7  G1  \
# 0        FEP25   3   3   3   3   2   3   1   1   1   1   3   4   1   1   1
# 1        FEP04   3   3   4   2   1   2   1   2   3   1   5   2   2   1   1
# 2          NaN   3   2   3   1   1   2   1   5   5   4   5   4   5   3   2
# 3          NaN   5   3   3   3   1   4   3   3   2   3   2   1   3   3   3
# 4        FEP07   2   1   1   1   1   3   2   3   1   2   1   4   3   1   2
# 5          NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 6        FEP28   5   2   4   2   4   4   2   3   3   3   4   1   2   1   4
# 7          NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 8        FEP03   4   2   3   1   1   2   1   1   2   1   2   3   1   1   1
# 9        FEP12   3   1   1   1   1   3   1   3   3   1   4   2   1   1   1
# 10       FEP01   4   2   1   1   1   3   1   2   2   1   1   2   1   1   1
# ...

# %% [markdown]
# ## Fibonacci number

# %%
a = [0]
b = 1
while b < 500:
    print a
    a.append(b)
    b = a[-1]+b
# Out:
# [0]
# [0, 1]
# [0, 1, 2]
# [0, 1, 2, 4]
# [0, 1, 2, 4, 8]
# [0, 1, 2, 4, 8, 16]
# [0, 1, 2, 4, 8, 16, 32]
# [0, 1, 2, 4, 8, 16, 32, 64]
# [0, 1, 2, 4, 8, 16, 32, 64, 128]

# %% [markdown]
# ## VBM

# %%
dataLocation='/Volumes/CCNC_3T/KangIk/2014_05_DKI_project/'

# %%
processedList = [x for x in os.listdir(dataLocation) if 'NOR' in x or 'FEP' in x]

# %%
subjectList = []

# %%
for processedSubject in processedList:
    for matchedSubject in matchedDf.subject:
        if processedSubject.startswith(matchedSubject):
            subjectList.append(processedSubject)

# %%
import shutil

# %%
for subject in subjectList:
    shutil.copy(os.path.join(subject,'DKI','kmean.nii'),
                os.path.join('VBM',subject+'_kmean.nii'))

# %%
cd VBM/
# Out:
# /Volumes/CCNC_3T/KangIk/2014_05_DKI_project/VBM

# %%
ls
# Out:
# FEP01_KWJ_kmean.nii* FEP18_LSY_kmean.nii* FEP35_LBR_kmean.nii* NOR18_JJM_kmean.nii* NOR56_YIW_kmean.nii*
# FEP02_IDH_kmean.nii* FEP19_LJY_kmean.nii* FEP36_LKJ_kmean.nii* NOR20_JJR_kmean.nii* NOR58_LMW_kmean.nii*
# FEP04_KSY_kmean.nii* FEP21_KHA_kmean.nii* FEP37_HJJ_kmean.nii* NOR24_YJA_kmean.nii* NOR60_KSH_kmean.nii*
# FEP05_JHR_kmean.nii* FEP22_JS_kmean.nii*  FEP38_HNS_kmean.nii* NOR26_YJH_kmean.nii* NOR61_KSH_kmean.nii*
# FEP06_LJY_kmean.nii* FEP23_CYJ_kmean.nii* FEP39_PJU_kmean.nii* NOR28_SHM_kmean.nii* NOR62_MBS_kmean.nii*
# FEP07_KHJ_kmean.nii* FEP24_CJY_kmean.nii* FEP40_KSB_kmean.nii* NOR34_CES_kmean.nii* NOR64_SSJ_kmean.nii*
# FEP08_JSM_kmean.nii* FEP25_KBK_kmean.nii* FEP41_KKH_kmean.nii* NOR36_HYS_kmean.nii* NOR65_LES_kmean.nii*
# FEP09_KHW_kmean.nii* FEP26_LNK_kmean.nii* NOR02_JIY_kmean.nii* NOR40_LJH_kmean.nii* NOR66_LDY_kmean.nii*
# FEP10_PHJ_kmean.nii* FEP27_LSK_kmean.nii* NOR03_LYE_kmean.nii* NOR41_SMH_kmean.nii* NOR67_LYE_kmean.nii*
# ...

# %%
mkdir T1

# %%
toConvert=[]

# %%
for subject in subjectList:
    try:
        if re.search('co',' '.join(os.listdir(os.path.join(subject,'T1')))):
            pass
        else:
            toConvert.append(subject)
    except:
        toConvert.append(subject)

# %%
toConvert
# Out:
# ['FEP37_HJJ',
#  'FEP38_HNS',
#  'FEP39_PJU',
#  'FEP40_KSB',
#  'FEP41_KKH',
#  'NOR34_CES',
#  'NOR36_HYS',
#  'NOR40_LJH',
#  'NOR41_SMH',
#  'NOR48_KTH',
#  'NOR74_LYN',
#  'NOR75_LSK',
#  'NOR76_KKT']

# %%
# !cat /Users/admin/.bash_profile|grep dcm2nii
# Out:
# alias dcm2nii='~/bin/mricron/dcm2nii'

# %%
for subject in toConvert:
    print subject
    output = os.popen('/Users/admin/bin/mricron/dcm2nii -o {subj}/T1 {subj}/T1/*'.format(subj=subject)).read()
    os.mkdir(os.path.join(subject,'T1','dicom'))
# Out:
# FEP37_HJJ
# FEP38_HNS
# FEP39_PJU
# FEP40_KSB
# FEP41_KKH
# NOR34_CES
# NOR36_HYS
# NOR40_LJH
# NOR41_SMH
# NOR48_KTH
# NOR74_LYN
# NOR75_LSK
# NOR76_KKT

# %%
for subject in subjectList:
    print subject
    for root,dirs,files in os.walk(subject):
        for oneFile in files:
            if re.search('^co2.*.nii.gz',oneFile):
                print oneFile
                shutil.copy(os.path.join(root,oneFile),
                            os.path.join('T1',subject+'.nii.gz'))
# Out:
# FEP01_KWJ
# co20100623_1819123DSPGR208SLABs004a1001.nii.gz
# FEP02_IDH
# co20100727_1322033DSPGR208SLABs004a1001.nii.gz
# FEP04_KSY
# co20101118_181444TFL3D208SLABs004a1001.nii.gz
# FEP05_JHR
# co20101217_182242TFL3D208SLABs004a1001.nii.gz
# FEP06_LJY
# co20101230_180829TFL3D208SLABs005a1001.nii.gz
# FEP07_KHJ
# co20110218_115324TFL3D208SLABs002a1001.nii.gz
# FEP08_JSM
# co20110307_174424TFL3D208SLABs004a1001.nii.gz
# FEP09_KHW
# co20110506_183007TFL3D208SLABs004a1001.nii.gz
# FEP10_PHJ
# co20110513_182348TFL3D208SLABs004a1001.nii.gz
# FEP11_KJY
# co20110516_181353TFL3D208SLABs004a1001.nii.gz
# FEP12_KAR
# co20110610_181824TFL3D208SLABs004a1001.nii.gz
# FEP13_LHJ
# co20111012_184840TFL3D208SLABs004a1001.nii.gz
# FEP14_LDE
# co20111128_183053TFL3D208SLABs004a1001.nii.gz
# FEP15_HJS
# co20111202_183606TFL3D208SLABs004a1001.nii.gz
# FEP16_JSW
# co20111221_183447TFL3D208SLABs004a1001.nii.gz
# FEP18_LSY
# co20120220_181046TFL3D208SLABs005a1001.nii.gz
# FEP19_LJY
# ...
