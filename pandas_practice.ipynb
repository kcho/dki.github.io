# %% [markdown]
# # Load libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load data

# %%
df = pd.read_excel("/Users/admin/Downloads/Untitled.xlsx",'Sheet1')

# %% [markdown]
# # Look at the data

# %%
print len(df),'lines of medication information'
df.head()
# Out:
# 12976 lines of medication information
#          id          med  amount
# 0  16857249    Lorazepam      21
# 1  16857249   Quetiapine      14
# 2  16857249  Risperidone      14
# 3  16857249    Lorazepam      15
# 4  16857249  Risperidone      42

# %% [markdown]
# # Pivot tables

# %%
pd.pivot_table(df, values='amount',index='id',columns='med',fill_value='missing',dropna=False,margins=True).head().ix[:,-10:]
# Out:
#          Risperidone Sertraline Topiramate Trazodone Trihexyphenidyl  \
# id
# 16857249    18.80556    missing    missing   missing         missing
# 30276738     missing    missing    missing   missing         missing
# 31596341    16.95192    missing      12.95   missing         missing
# 33068859     missing    missing    missing   missing         missing
# 33319982     missing    missing    missing   missing         missing
#
#          Valproate Venlafaxine Ziprasidone Zolpidem        All
# id
# 16857249   missing     missing     missing  missing  18.716667
# 30276738   missing     missing     missing  missing  17.500000
# 31596341    20.125     missing     missing  missing  17.720486
# 33068859   missing     missing     missing  missing  15.910000
# 33319982   missing     missing    23.21429  missing  23.034483

# %%
pd.pivot_table(df, values='amount',index='id',columns='med',aggfunc=np.sum,dropna=False,margins=True).head().ix[:,-10:]
# Out:
#           Risperidone  Sertraline  Topiramate  Trazodone  Trihexyphenidyl  \
# id
# 16857249       338.50         NaN         NaN        NaN              NaN
# 30276738          NaN         NaN         NaN        NaN              NaN
# 31596341      1322.25         NaN       129.5        NaN              NaN
# 33068859          NaN         NaN         NaN        NaN              NaN
# 33319982          NaN         NaN         NaN        NaN              NaN
#
#           Valproate  Venlafaxine  Ziprasidone  Zolpidem     All
# id
# 16857249        NaN          NaN          NaN       NaN  1123.0
# 30276738        NaN          NaN          NaN       NaN   315.0
# 31596341        161          NaN          NaN       NaN  5103.5
# 33068859        NaN          NaN          NaN       NaN   795.5
# 33319982        NaN          NaN          325       NaN  1336.0

# %% [markdown]
# ## 'dropna' option check

# %%
dropTrue=pd.pivot_table(df, values='amount',index='id',columns='med',aggfunc=np.sum,dropna=True,margins=True)
dropFalse=pd.pivot_table(df, values='amount',index='id',columns='med',aggfunc=np.sum,dropna=False,margins=True)

print len(dropTrue),len(dropFalse)
# Out:
# 80 80

# %%
print len(dropTrue.columns),len(dropFalse.columns)
# Out:
# 42 42

# %% [markdown]
# # Groupby function

# %%
print len(df)
# Out:
# 12976

# %%
df.groupby('med').size().head()
# Out:
# med
# Alprazolam       145
# Amisulpride      186
# Amitriptyline      4
# Aripiprazole     972
# Benztropine       84
# dtype: int64

# %%
gb = df.groupby('med')

# %%
gb.agg(np.sum).head()
# Out:
#                         id   amount
# med
# Alprazolam      8172999103   2601.5
# Amisulpride    13062115298   5396.0
# Amitriptyline    171628112     98.0
# Aripiprazole   47061567951  22636.0
# Benztropine     3447025896   1808.0

# %% [markdown]
# ## Group by other categories

# %% [markdown]
# #### Number of medication types

# %%
len(df.med.drop_duplicates())
# Out:
# 41

# %% [markdown]
# #### Random criteria make up

# %%
numCategory = np.random.randint(1,5,size=41)
numCategory
# Out:
# array([3, 4, 3, 3, 1, 1, 3, 1, 4, 1, 1, 3, 1, 2, 3, 4, 4, 1, 2, 4, 1, 1, 4,
#        1, 3, 3, 2, 2, 4, 4, 3, 1, 2, 3, 3, 1, 3, 4, 2, 2, 3])

# %% [markdown]
# #### Price tag

# %%
numToStrength={1:'high',
               2:'medium',
               3:'low',
               4:'zero'}

# %% [markdown]
# #### Make into dictionary

# %%
map_dictionary = dict(zip(df.med.drop_duplicates().tolist(),[numToStrength[x] for x in numCategory]))

# %% [markdown]
# #### Groupby the category

# %%
gb = df.set_index('med').groupby(map_dictionary)
gb.sum()
# Out:
#                   id    amount
# high    197726831078   87846.5
# low     277840111105  130155.5
# medium   19611607026    9883.5
# zero    154958308882   70066.0

# %% [markdown]
# ## Groupby other technique

# %%
gb = df.groupby(['id','med'])

# %% [markdown]
# ## Pivot tables

# %%
# Out:
#                              amount
# id       med
# 16857249 Escitalopram     20.571429
#          Lorazepam        21.937500
#          Olanzapine       17.500000
#          Quetiapine       11.050000
#          Risperidone      18.805556
# 30276738 Quetiapine       17.500000
# 31596341 Aripiprazole     20.150000
#          Benztropine      13.000000
#          Clonazepam       22.604167
#          Escitalopram     18.562500
#          Lorazepam        16.018382
#          Propranolol      17.125000
#          Risperidone      16.951923
#          Topiramate       12.950000
#          Valproate        20.125000
# 33068859 Escitalopram     15.750000
#          Quetiapine       15.923913
# 33319982 Aripiprazole     28.250000
#          Fluoxetine       20.678571
#          Lorazepam        23.403846
#          Ziprasidone      23.214286
# 33364292 Aripiprazole     29.900000
#          Lorazepam        16.287500
#          Olanzapine       19.821429
# 33674829 Benztropine      24.916667
#          Clonazepam       16.350000
#          Lorazepam        14.850000
#          Risperidone      16.818182
#          Trihexyphenidyl  18.178571
# 33795447 Lorazepam        17.226415
# ...                             ...
# 73854205 Olanzapine       42.500000
#          Quetiapine       37.870968
#          Ziprasidone      30.833333
# 73887306 Escitalopram     56.000000
# 74306545 Clonazepam       25.333333
#          Diazepam         27.000000
#          Escitalopram     41.659091
#          Fluoxetine       37.625000
#          Lorazepam        23.156250
#          Modafinil        17.500000
#          Olanzapine       24.941667
#          Sertraline       19.272727
#          Zolpidem         17.750000
# 74517321 Alprazolam        8.250000
#          Aripiprazole     27.677632
#          Benztropine      31.500000
#          Fluoxetine       22.841667
#          Lorazepam        19.616935
#          Olanzapine       17.916667
#          Paliperidone     14.250000
#          Propranolol      24.220000
#          Trihexyphenidyl  11.857143
#          Ziprasidone      23.500000
# 74595857 Aripiprazole     20.555556
#          Clonazepam       16.950000
#          Fluoxetine       17.580000
#          Lorazepam        17.375000
#          Olanzapine       10.500000
#          Propranolol      12.878788
#          Risperidone      11.625000
#
# [419 rows x 1 columns]
